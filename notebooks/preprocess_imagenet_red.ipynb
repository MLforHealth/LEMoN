# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split

## change and re-run
# img_dir = Path('/data/healthy-ml/gobi1/data/ImageNetRed/dataset_no_images/mini-imagenet/')
# df = pd.read_json('/data/healthy-ml/gobi1/data/ImageNetRed/dataset_no_images/mini-imagenet-annotations.json')

img_dir = Path('/data/healthy-ml/gobi1/data/ImageNetRed/dataset_no_images/stanford_cars/')
df = pd.read_json('/data/healthy-ml/gobi1/data/ImageNetRed/dataset_no_images/stanford-cars-annotations.json')

df = pd.DataFrame(df['data'].apply(lambda x: x[0]).tolist())
df.columns = ['url', 'id', 'label', 'is_clean']

# %%
all_jpgs = list(img_dir.glob('**/*.jpg'))

# %%
all_jpgs_mapping = pd.Series({int(i.with_suffix('').name):str(i) for i in all_jpgs})

# %%
df['path'] = all_jpgs_mapping

# %%
df = df.dropna(subset = ['path']).reset_index()

# %%
df.shape

# %%
df

# %%
df.to_csv(img_dir/'multimodal_mislabel_split.csv', index = False)
